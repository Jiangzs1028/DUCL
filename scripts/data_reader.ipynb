# %%
import pandas as pd

# %%
df = pd.read_json("./result/result-test1.jsonl", lines=True)
df = df.sort_values(by="DUE", ascending=True)

# %%
df
# Out:
#                                                   text    label  difficulty  \
# 495  . Although the technique originated in the Sel...  webmath    0.228797
# 144  ically or by substitution.\n\n### 4.\n\nPause ...  webmath    0.226143
# 146   Golden Rectangle and Donald Duck.\n\n@theorem...  webmath    0.238801
# 406  10.3 Independent Sets: Properties and Algorith...  webmath    0.246770
# 63   O, tone detection\n\nI have had an interest in...  webmath    0.248357
# ..                                                 ...      ...         ...
# 78    GeoTiffs. This is reflected throughout the Ge...  webmath    0.452439
# 460  .0000 1.0000 1.0000 1.0000 1.0000\n14 1.0000 1...  webmath    0.557615
# 324   association between race and season for diagn...  webmath    0.327078
# 387   in the first frame, the corresponding equatio...  webmath    0.535870
# 107  �□□□□□□□□□□□□□□□□□□□□\n□□□□□□□□□□□□□□□□□□□□□□□...  webmath    0.579186
#
#           utility           DUE
# ...
