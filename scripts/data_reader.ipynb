# %%
import pandas as pd

# %%
df = pd.read_json("../result/result-test.jsonl", lines=True)
df = df.sort_values(by="DUE", ascending=True)

# %%
df
# Out:
#                                                   text    label  difficulty  \
# 175   gentleman adventurer who uses pip.\n\n$pip in...  webmath    0.191717
# 276   Scientific Research (CNRS) in Paris. In addit...  webmath    0.201081
# 237   to put in some text explanations. The easiest...  webmath    0.205989
# 143  ically or by substitution.\n\n### 4.\n\nPause ...  webmath    0.197340
# 267   and prior reservoir production. Using Young's...  webmath    0.205250
# ..                                                 ...      ...         ...
# 242  100. If you are looking to convert 1/5, then 1...  webmath    0.464935
# 150  (\mathbb{Z} ,IntegerAddition,IntegerOrder)$$, ...  webmath    0.444141
# 44    Mole Concept The Mole. The mass of a single n...  webmath    0.450632
# 322   association between race and season for diagn...  webmath    0.329514
# 106  �□□□□□□□□□□□□□□□□□□□□\n□□□□□□□□□□□□□□□□□□□□□□□...  webmath    0.602275
#
#       utility         DUE
# 175  0.359276    0.533621
# ...
